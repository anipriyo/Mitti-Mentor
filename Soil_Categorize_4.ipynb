# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ['alluvial', 'black', 'clay', 'red']
img_size = 224

def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        print(path)
        print(os.listdir(path))
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1]
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except:
                print(Exception)
    return np.array(data, dtype=object)

# %%
print(os.getcwd())
# Out:
# /content

# %%
train = get_data('/content/drive/MyDrive/soil_dataset_3/train')
val = get_data('/content/drive/MyDrive/soil_dataset_3/test')
# Out:
# /content/drive/MyDrive/soil_dataset_3/train/alluvial
# ['Alluvial_18.jpg', 'Alluvial_33.jpg', 'Alluvial_37.jpg', 'Alluvial_43.jpg', 'Alluvial_46.jpg', 'Alluvial_26.jpg', 'Alluvial-soil-distribution-in-India.jpg', 'Alluvial_24.jpg', 'Alluvial_34.jpg', 'Alluvial_25.jpg', 'Alluvial_1.jpg', 'Alluvial_39.jpg', 'Alluvial_2.jpg', 'Alluvial_23.jpg', 'Alluvial_22.jpg', 'Alluvial_53.jpg', 'Alluvial_7.jpg', '01060602previewen-02d.jpg', '1000_F_240425429_YL91trtDxXQl8L0OKP7zyngeSb63olAC.jpg', 'Alluvial_45.jpg', 'Alluvial-Soil..png', 'Alluvial_21.jpg', 'Alluvial_3.jpg', 'Alluvial_30.jpg', 'Alluvial_48.jpg', 'Alluvial_40.jpg', 'Alluvial_47.jpg', 'Alluvial_42.jpg', 'Alluvial_35.jpg', 'Alluvial-soil-distribution-in-India-1.jpeg', 'Alluvial_11.jpg', 'Alluvial_20.jpg', 'Alluvial_17.jpg', 'Alluvial_12.jpg', 'Alluvial_13.jpg', 'Alluvial_4.jpg', 'Alluvial_14.jpg', 'Alluvial_15.jpg', 'Alluvial_31.jpg', 'Alluvial_38.jpg', '01060602previewen-02b.jpg', 'Alluvial_16.jpg', 'Alluvial_41.jpg', 'Alluvial_36.jpg', 'Alluvial_6.jpg', 'Alluvial_19.jpg', 'Alluvial_5.jpg', 'Alluvial_50.jpg', 'Alluvial_10.jpg', 'Alluvial_44.jpg', 'Alluvial_8.jpg', 'Alluvial_9.jpg', 'IMG-20220531-WA0043.jpg', 'IMG-20220531-WA0017.jpg', 'image3 (2).jpeg', 'images86.jpg', 'images78 (2).jpg', 'Sample9.0.jpg', 'image30 (2).jpeg', 'Photograph-showing-the-presence-of-alluvial-soil-along-stream-course-dry-near-Patlodha_Q640.jpg', 'IMG-20220531-WA0094.jpg', 'alluvial-soil-1kg-green-era-original-imag4r54hhybzhqc.jpeg', 'photo_2022-06-01_07-04-46.jpg', 'photo_2022-06-01_07-06-27.jpg', 'alluvial-diamond-layers-mining-site-western-cape-south-africa-G8CR87.jpg', 'images96.jpg', 'desktop_137249cc-6732-40b3-94e1-1381ad82c07f.jpg', 'images105.jpg', 'image6 (2).jpeg', 'images77 (2).jpg', 'image14 (3).jpeg', 'close-up-of-alluvial-soil-as-a-texturebackground-JCB3RY.jpg', 'alluvial-soil-profile-agricultural-land-260nw-1867228486.jpg', 'image7 (2).jpeg', 'images21.jpg', 'Sample13.0.jpg', 'image16 (2).jpeg', 'images76 (2).jpg', 'seamless-texture-dry-cracked-sand-clay-soil_
'Clay_27.jpg', 'Clay_36.jpg', 'Clay_30.jpg', 'Clay_32.jpg', 'Clay_24.jpg', 'Clay_44.jpg', 'Clay_5.jpg', 'Clay_11.jpg', 'clay-soil-cut-red-color-clay-clay-soil-cut-red-color-clay-184254602.jpg', 'Clay_19.jpg', 'clay-soil-field.jpg', 'Clay_18.jpg', 'Clay_1.jpg', 'Clay_12.jpg', 'image23 (2).jpeg', 'clay-soil-close-up-brown-179039817.jpg', 'Clay_20.jpg', 'Sample1.120.jpg', 'Clay_15.jpg', 'Clay_4.jpg', 'Clay_9.jpg', 'red-clay-soil-closeup-red-clay-soil-closeup-as-natural-background-98921605.jpg', 'Clay_6.jpg', 'Clay_46.jpg', 'images72.jpg', 'Clay_45.jpg', 'Clay_47.jpg', 'Clay_3.jpg', 'Clay_14.jpg', 'Clay_13.jpg', 'Clay_8.jpg', 'Clay_21.jpg', 'Clay_10.jpg', 'Clay_17.jpg', 'Clay_16.jpg']
# /content/drive/MyDrive/soil_dataset_3/test/red
# ['95424d278d0b71fa4b398f406303a4a9.jpg', '2560px-A_red_soil_crop_field.JPG.jpg', '1000_F_233167094_JhQz9xvHtlN5UyT3zt748JiJolOSid7s.jpg', '835254_2.jpg', 'Red_37.jpg', 'Red_28.jpg', 'images189.jpg', 'red-soil-background-6402446.jpg', 'Red_16.jpg', 'Red_3.jpg', 'Red_46.jpg', 'utkl.jpg', 'Red_8.jpg', 'Red_20.jpg', 'Red_44.jpg', 'Nc-red-clay-soil-2.jpg', 'Red-soil-essay.jpg', 'Red_15.jpg', 'Red_32.jpg', 'red20clay-700x700.jpg', 'Red_19.jpg', 'images195.jpg', 'red-soil-1.gif', 'Red_21.jpg', 'Sample6.0.jpg', 'images183.jpg', 'red-soil-500x5003.jpg', 'Red_39.jpg', 'red-ground-texture-260nw-1079913677.jpg', 'images177.jpg', 'Red_9.jpg', 'Red_41.jpg', 'Red_31.jpg', 'Red_35.jpg', 'Red_13.jpg', 'Red_23.jpg', 'red3.jpg', 'Red_30.jpg', 'Red_29.jpg', 'images192.jpg', 'Red_27.jpg', 'images202.jpg', 'Red_24.jpg', 'Red_18.jpg', 'Red_5.jpg', 'red-soil-500x5002.jpg', 'Red_43.jpg', 'Red_14.jpg', 'Red_36.jpg', 'Red_22.jpg', 'Red_42.jpg', 'Red_40.jpg', 'Red_7.jpg', 'images191.jpg', 'Red_6.jpg', 'images188.jpg', 'Red_11.jpg', 'Red_4.jpg', 'Red_1.jpg']

# %%
print(len(val))
# Out:
# 201

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("alluvial")
    elif (i[1] == 1):
        l.append("black")
    elif (i[1] == 2):
        l.append("clay")
    else:
        l.append("red")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# <Axes: xlabel='count'>

# %%
xtrain = []
ytrain = []
xval = []
yval = []

for feature, label in train:
    xtrain.append(feature)
    ytrain.append(label)

for feature, label in val:
    xval.append(feature)
    yval.append(label)

xtrain = np.array(xtrain) / 255
xval = np.array(xval) / 255

xtrain.reshape(-1, img_size, img_size, 1)
ytrain = np.array(ytrain)

xval.reshape(-1, img_size, img_size, 1)
yval = np.array(yval)

ytrain = keras.utils.to_categorical(ytrain, 4)
yval = keras.utils.to_categorical(yval, 4)

# %%
print(len(xval))
# Out:
# 201

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(xtrain)

# %%
# model= Sequential()
# model.add(Conv2D(kernel_size=(3,3), filters=32, activation='tanh', input_shape=(224,224,3)))
# model.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))
# model.add(MaxPool2D(2,2))
# model.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))
# model.add(MaxPool2D(2,2))
# model.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))

# model.add(Flatten())

# model.add(Dense(20,activation='relu'))
# model.add(Dense(15,activation='relu'))
# model.add(Dense(4,activation = 'softmax'))

# model.compile(
#               loss='categorical_crossentropy',
#               metrics=['acc'],
#               optimizer='adam'
#              )
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(img_size,img_size,3)))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(4))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation('softmax'))

model.compile(keras.optimizers.Adam(learning_rate=1e-5), 'categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 786432)            0
#
#  batch_normalization (Batch  (None, 786432)            3145728
#  Normalization)
#
#  dense (Dense)               (None, 4)                 3145732
#
#  batch_normalization_1 (Bat  (None, 4)                 16
#  chNormalization)
#
#  activation (Activation)     (None, 4)                 0
#
# =================================================================
# Total params: 6291476 (24.00 MB)
# Trainable params: 4718604 (18.00 MB)
# Non-trainable params: 1572872 (6.00 MB)
# _________________________________________________________________

# %%
history = model.fit(xtrain,ytrain,epochs = 50, validation_data = (xval, yval))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 12s 689ms/step - loss: 1.0961 - accuracy: 0.6014 - val_loss: 1.3057 - val_accuracy: 0.5473
# Epoch 2/50
# 14/14 [==============================] - 7s 510ms/step - loss: 0.9518 - accuracy: 0.6982 - val_loss: 1.1221 - val_accuracy: 0.5920
# Epoch 3/50
# 14/14 [==============================] - 8s 576ms/step - loss: 0.9310 - accuracy: 0.6889 - val_loss: 1.0693 - val_accuracy: 0.5871
# Epoch 4/50
# 14/14 [==============================] - 7s 513ms/step - loss: 0.8719 - accuracy: 0.7327 - val_loss: 1.0391 - val_accuracy: 0.5920
# Epoch 5/50
# 14/14 [==============================] - 8s 573ms/step - loss: 0.8365 - accuracy: 0.7442 - val_loss: 1.0281 - val_accuracy: 0.6020
# Epoch 6/50
# 14/14 [==============================] - 7s 518ms/step - loss: 0.7685 - accuracy: 0.7696 - val_loss: 1.0510 - val_accuracy: 0.5920
# Epoch 7/50
# 14/14 [==============================] - 9s 674ms/step - loss: 0.7328 - accuracy: 0.7857 - val_loss: 1.0172 - val_accuracy: 0.6866
# Epoch 8/50
# 14/14 [==============================] - 9s 687ms/step - loss: 0.6999 - accuracy: 0.7903 - val_loss: 1.0163 - val_accuracy: 0.7910
# Epoch 9/50
# 14/14 [==============================] - 8s 528ms/step - loss: 0.6412 - accuracy: 0.8295 - val_loss: 1.0317 - val_accuracy: 0.8507
# Epoch 10/50
# 14/14 [==============================] - 8s 577ms/step - loss: 0.5886 - accuracy: 0.8687 - val_loss: 1.0371 - val_accuracy: 0.8756
# Epoch 11/50
# 14/14 [==============================] - 8s 592ms/step - loss: 0.5299 - accuracy: 0.9171 - val_loss: 1.0185 - val_accuracy: 0.9353
# Epoch 12/50
# 14/14 [==============================] - 8s 574ms/step - loss: 0.4912 - accuracy: 0.9309 - val_loss: 1.0016 - val_accuracy: 0.9502
# Epoch 13/50
# 14/14 [==============================] - 7s 471ms/step - loss: 0.4672 - accuracy: 0.9332 - val_loss: 0.9714 - val_accuracy: 0.9552
# Epoch 14/50
# 14/14 [==============================] - 9s 623ms/step - loss: 0.4506 - accuracy: 0.9424 - val_loss: 0.9623 - val_accuracy: 0.9701
# Epoch 15/50
# 14/14 [==============================] - 7s 517ms/step - loss: 0.4200 - accuracy: 0.9585 - val_loss: 0.9286 - val_accuracy: 0.9801
# Epoch 16/50
# 14/14 [==============================] - 8s 543ms/step - loss: 0.4287 - accuracy: 0.9608 - val_loss: 0.9078 - val_accuracy: 0.9801
# Epoch 17/50
# 14/14 [==============================] - 7s 520ms/step - loss: 0.3910 - accuracy: 0.9724 - val_loss: 0.9031 - val_accuracy: 0.9801
# Epoch 18/50
# 14/14 [==============================] - 7s 532ms/step - loss: 0.4098 - accuracy: 0.9700 - val_loss: 0.8546 - val_accuracy: 0.9801
# Epoch 19/50
# 14/14 [==============================] - 7s 533ms/step - loss: 0.4125 - accuracy: 0.9654 - val_loss: 0.8378 - val_accuracy: 0.9801
# Epoch 20/50
# 14/14 [==============================] - 8s 550ms/step - loss: 0.3801 - accuracy: 0.9724 - val_loss: 0.8191 - val_accuracy: 0.9851
# Epoch 21/50
# 14/14 [==============================] - 8s 577ms/step - loss: 0.3727 - accuracy: 0.9862 - val_loss: 0.8267 - val_accuracy: 0.9851
# Epoch 22/50
# 14/14 [==============================] - 7s 515ms/step - loss: 0.3564 - accuracy: 0.9885 - val_loss: 0.7660 - val_accuracy: 0.9900
# Epoch 23/50
# 14/14 [==============================] - 8s 574ms/step - loss: 0.3696 - accuracy: 0.9885 - val_loss: 0.7347 - val_accuracy: 0.9801
# Epoch 24/50
# 14/14 [==============================] - 7s 466ms/step - loss: 0.3743 - accuracy: 0.9862 - val_loss: 0.6751 - val_accuracy: 0.9900
# Epoch 25/50
# 14/14 [==============================] - 8s 572ms/step - loss: 0.3711 - accuracy: 0.9839 - val_loss: 0.6170 - val_accuracy: 0.9851
# Epoch 26/50
# 14/14 [==============================] - 7s 469ms/step - loss: 0.3482 - accuracy: 0.9977 - val_loss: 0.6809 - val_accuracy: 0.9900
# Epoch 27/50
# 14/14 [==============================] - 9s 628ms/step - loss: 0.3419 - accuracy: 0.9908 - val_loss: 0.6080 - val_accuracy: 0.9900
# Epoch 28/50
# 14/14 [==============================] - 7s 520ms/step - loss: 0.3459 - accuracy: 0.9931 - val_loss: 0.5917 - val_accuracy: 0.9851
# Epoch 29/50
# 14/14 [==============================] - 8s 579ms/step - loss: 0.3408 - accuracy: 0.9954 - val_loss: 0.5417 - val_accuracy: 0.9900
# Epoch 30/50
# 14/14 [==============================] - 7s 470ms/step - loss: 0.3274 - accuracy: 1.0000 - val_loss: 0.5241 - val_accuracy: 0.9900
# Epoch 31/50
# 14/14 [==============================] - 9s 623ms/step - loss: 0.3143 - accuracy: 0.9954 - val_loss: 0.5852 - val_accuracy: 0.9851
# Epoch 32/50
# 14/14 [==============================] - 7s 471ms/step - loss: 0.3281 - accuracy: 0.9931 - val_loss: 0.5369 - val_accuracy: 0.9801
# Epoch 33/50
# 14/14 [==============================] - 9s 628ms/step - loss: 0.3650 - accuracy: 0.9700 - val_loss: 0.4586 - val_accuracy: 0.9851
# Epoch 34/50
# 14/14 [==============================] - 7s 478ms/step - loss: 0.3323 - accuracy: 0.9908 - val_loss: 0.4393 - val_accuracy: 0.9900
# Epoch 35/50
# 14/14 [==============================] - 9s 603ms/step - loss: 0.3241 - accuracy: 0.9908 - val_loss: 0.4624 - val_accuracy: 0.9900
# Epoch 36/50
# 14/14 [==============================] - 7s 508ms/step - loss: 0.3129 - accuracy: 0.9977 - val_loss: 0.4495 - val_accuracy: 0.9950
# Epoch 37/50
# 14/14 [==============================] - 8s 577ms/step - loss: 0.3328 - accuracy: 1.0000 - val_loss: 0.4041 - val_accuracy: 0.9851
# Epoch 38/50
# 14/14 [==============================] - 7s 531ms/step - loss: 0.3256 - accuracy: 0.9977 - val_loss: 0.3339 - val_accuracy: 0.9851
# Epoch 39/50
# 14/14 [==============================] - 7s 504ms/step - loss: 0.3340 - accuracy: 0.9954 - val_loss: 0.3969 - val_accuracy: 0.9900
# Epoch 40/50
# 14/14 [==============================] - 8s 559ms/step - loss: 0.3199 - accuracy: 1.0000 - val_loss: 0.3718 - val_accuracy: 0.9900
# Epoch 41/50
# 14/14 [==============================] - 8s 534ms/step - loss: 0.3148 - accuracy: 1.0000 - val_loss: 0.3607 - val_accuracy: 0.9851
# Epoch 42/50
# 14/14 [==============================] - 8s 605ms/step - loss: 0.3185 - accuracy: 0.9977 - val_loss: 0.3399 - val_accuracy: 0.9900
# Epoch 43/50
# 14/14 [==============================] - 7s 516ms/step - loss: 0.3140 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9950
# Epoch 44/50
# 14/14 [==============================] - 9s 626ms/step - loss: 0.3075 - accuracy: 1.0000 - val_loss: 0.3265 - val_accuracy: 0.9900
# Epoch 45/50
# 14/14 [==============================] - 7s 517ms/step - loss: 0.3066 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9900
# Epoch 46/50
# 14/14 [==============================] - 8s 578ms/step - loss: 0.3139 - accuracy: 0.9977 - val_loss: 0.3189 - val_accuracy: 0.9851
# Epoch 47/50
# 14/14 [==============================] - 7s 489ms/step - loss: 0.3133 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9900
# Epoch 48/50
# 14/14 [==============================] - 9s 643ms/step - loss: 0.3124 - accuracy: 1.0000 - val_loss: 0.3313 - val_accuracy: 0.9950
# Epoch 49/50
# 14/14 [==============================] - 7s 480ms/step - loss: 0.3075 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.9900
# Epoch 50/50
# 14/14 [==============================] - 8s 543ms/step - loss: 0.3124 - accuracy: 0.9954 - val_loss: 0.3428 - val_accuracy: 0.9851

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Evaluating model on validation data
evaluate = model.evaluate(xval,yval)
print(evaluate)
# Out:
# 7/7 [==============================] - 1s 106ms/step - loss: 0.3428 - accuracy: 0.9851
# [0.34280532598495483, 0.9850746393203735]

# %%
checkImage = xval[99:100]
checklabel = yval[99:100]

predict = model.predict(np.array(checkImage))

output = { 0:'alluvial',1:'black',2:'clay',3:'red'}

print("Actual    :- ",output[np.argmax(checklabel)])
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Actual    :-  clay
# Predicted :-  clay

# %%
i=4
model_loc='/content/drive/MyDrive/Models/'
path=os.listdir(model_loc)
for j in path:
  if(j.endswith('.h5')):
    i=i+1
model.save(model_loc+"soilClassify_"+str(i)+".h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import cv2
import numpy as np

i=3
model_loc='/content/drive/MyDrive/Models/'
path=os.listdir(model_loc)
for j in path:
  if(j.endswith('.h5')):
    i=i+1

from keras.models import load_model
model = load_model(model_loc+"soilClassify_"+str(i)+".h5")
# latest model loaded

output = { 0:'alluvial',1:'black',2:'clay',3:'red'}

imgPath='/content/drive/MyDrive/Colab Notebooks/BST2.webp'
img=cv2.imread(imgPath)
# Check if the image is loaded successfully
if img is None:
  print("Image not loaded. Please check the path and try again.")
  exit()
checkImage=cv2.resize(img, (img_size, img_size));
checkImage = np.expand_dims(checkImage, axis=0)
print(checkImage.shape)
predict=model.predict(np.array(checkImage))
print("Prediction List : ",predict)
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# (1, 512, 512, 3)
# 1/1 [==============================] - 0s 136ms/step
# Prediction List :  [[0. 1. 0. 0.]]
# Predicted :-  black

# %%
import cv2
import numpy as np

i=3
model_loc='/content/drive/MyDrive/Models/'
path=os.listdir(model_loc)
for j in path:
  if(j.endswith('.h5')):
    i=i+1

from keras.models import load_model
model = load_model(model_loc+"soilClassify_"+str(i)+".h5")
# latest model loaded

output = { 0:'alluvial',1:'black',2:'clay',3:'red'}
labels = ['alluvial', 'black', 'clay', 'red']

for label in labels:
  for img in folder:
    imgPath=os.path.join("/content/drive/MyDrive/Colab Notebooks/"+label+"/",img)
    img=cv2.imread(imgPath)
    # Check if the image is loaded successfully
    if img is None:
      print("Image not loaded. Please check the path and try again.")
      exit()
    checkImage=cv2.resize(img, (img_size, img_size));
    checkImage = np.expand_dims(checkImage, axis=0)
    print(checkImage.shape)
    predict=model.predict(np.array(checkImage))
    print("Prediction List : ",predict)
    print("Predicted :- ",output[np.argmax(predict)])
    print("Actual    :-",label)
    print()

# %%
#Best Model so far
import cv2
import numpy as np

img_size=224
model_loc="/content/drive/MyDrive/Models/"

from keras.models import load_model
model = load_model(model_loc+"soilClassify_2.h5")
# latest model loaded

output = { 0:'alluvial',1:'black',2:'clay',3:'red'}

imgPath='/content/drive/MyDrive/Colab Notebooks/BST1.webp'
img=cv2.imread(imgPath)
# Check if the image is loaded successfully
if img is None:
  print("Image not loaded. Please check the path and try again.")
  exit()
checkImage=cv2.resize(img, (img_size, img_size));
checkImage = np.expand_dims(checkImage, axis=0)
print(checkImage.shape)
predict=model.predict(np.array(checkImage))
print("Prediction List : ",predict)
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 74ms/step
# Prediction List :  [[9.9999952e-01 0.0000000e+00 4.3157556e-07 0.0000000e+00]]
# Predicted :-  alluvial
